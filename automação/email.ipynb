# %%
#importando bibliotecas
import pyautogui as pg
import time
import pyperclip

pg.PAUSE = 1

#abrir navegador
#pg.press('winleft')
#pg.write("chrome")
#pg.press('enter')
pg.alert('Vai começar, aperte ok e não mexa em nada')
pg.hotkey('ctrl','t') 

# abriu o link e esperou carregar
link = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyperclip.copy(link)
pg.hotkey('ctrl','v')
pg.press('enter')
time.sleep(7)

#abriu a pagina exportar
pg.click(x=377, y=387, clicks=2)
pg.click(x=377, y=387)
pg.click(x=1161, y=158)
pg.click(x=957, y=563)

#baixou o arquivo

# %%
#importar bd
import pandas as pd
dd = pd.read_excel(r'C:\Users\rafae_000\Downloads\Vendas - Dez.xlsx')
display(dd)

fat = dd['Valor Final'].sum()
qtd = dd['Quantidade'].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#abrindo o gmail
pg.hotkey('ctrl','t')
pg.write('https://mail.google.com/mail/u/0/#inbox')
pg.press('enter')
time.sleep(5)

#mandando email
pg.click(x=100, y=172)
pg.write('rafaelfsteffens@gmail.com')
time.sleep(1)
pg.press('tab')
time.sleep(1)
pg.press('tab')
time.sleep(1)
pg.write('Urgente')
time.sleep(1)
pg.press('tab')

texto = f'''
Bom dia,
o faturamento de ontem foi R$ {fat:,.1f}
e tivemos {qtd:,} quantidades vendidas ontem

atenciosamente
Rafael Steffens

'''
pyperclip.copy(texto)
pg.hotkey('ctrl', 'v')
pg.click (x=206, y=596)

# %% [markdown]
# Agora vamos descobrir as posições

# %%
#time.sleep(5)
#pg.position()
